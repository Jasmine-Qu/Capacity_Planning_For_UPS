# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from gurobipy import *
import time
import datetime
import scipy.stats as st
from fitter import Fitter

import warnings
warnings.filterwarnings("ignore")

# %%
data=pd.read_csv('demand_ups.csv')
data.head()
# Out:
#    Unnamed: 0              Lane        date    real_d  predict_d  weekday  \
# 0           0  SCN-SZX HUB (US)  2019-01-01       0.0     8247.0      2.0
# 1           1  SCN-SZX HUB (US)  2019-01-02       0.0   131205.0      3.0
# 2           2  SCN-SZX HUB (US)  2019-01-03  589810.0   334451.0      4.0
# 3           3  SCN-SZX HUB (US)  2019-01-04  501838.0   315303.0      5.0
# 4           4  SCN-SZX HUB (US)  2019-01-05  616311.0   402192.0      6.0
#
#    month    year  quarter  period
# 0    1.0  2019.0      1.0     1.0
# 1    1.0  2019.0      1.0     1.0
# 2    1.0  2019.0      1.0     1.0
# 3    1.0  2019.0      1.0     1.0
# 4    1.0  2019.0      1.0     1.0

# %%
#We just select SZX-US and HK-US two lanes
#input: 1,3,SZX/US,(default:2019),predict/real

# eg. df=data_select(1,3,2019,'SZX','predict')

lane_dict={'SZX':'SCN-SZX HUB (US)','HK':'HK HUB (US)'}
type_dict={'predict':'predict_d','real':'real_d'}

def data_select(weekday,period,year,lane,datatype='predict'):   
    df=data[(data['Lane']==lane_dict[lane]) & (data['weekday']==weekday) 
            &(data['period']==period) &(data['year']==year)]
    column=['Lane', 'date',type_dict[datatype] ,'weekday', 'month', 'year',
       'quarter', 'period']
    df=df[column]
    df=df[(df[type_dict[datatype]]>=1000)]
    df.reset_index(drop=True,inplace=True)
    df=df.rename(columns={type_dict[datatype]:'demand'})
    return df

# %%
df=data_select(1,3,2019,'SZX','predict')
df.head(5)
# Out:
#                Lane        date    demand  weekday  month    year  quarter  \
# 0  SCN-SZX HUB (US)  2019-10-14  374052.0      1.0   10.0  2019.0      4.0
# 1  SCN-SZX HUB (US)  2019-10-21  382281.0      1.0   10.0  2019.0      4.0
# 2  SCN-SZX HUB (US)  2019-10-28  378191.0      1.0   10.0  2019.0      4.0
# 3  SCN-SZX HUB (US)  2019-11-04  377295.0      1.0   11.0  2019.0      4.0
# 4  SCN-SZX HUB (US)  2019-11-11  554677.0      1.0   11.0  2019.0      4.0
#
#    period
# 0     3.0
# 1     3.0
# 2     3.0
# 3     3.0
# 4     3.0

# %%
df=data_select(1,3,2019,'SZX','real')
df.head(5)
x_predict=0

# %%
def flexibility_model(demand,c,cost_over,cost_under):
    ######### Model Set-up ############
    m = Model()
    M=1e20

    #flexibility
    x = m.addVar(vtype=GRB.CONTINUOUS,name = "flexibility")#x
    y1= m.addVars(2,vtype=GRB.CONTINUOUS,name = "y1")
    y2= m.addVars(2,vtype=GRB.CONTINUOUS,name = "y2")
    z1 = m.addVars(2,2,vtype=GRB.BINARY,name='z1')
    z2 = m.addVars(2,2,vtype=GRB.BINARY,name='z2')

    # set objective
    m.setObjective( quicksum((cost_over[t]*y1[t]+cost_under[t]*y2[t]) for t in range(2)), GRB.MINIMIZE)#

    # add constraint
    
    m.addConstrs( y1[t]>=c[t]-demand[t]+x*((-1)**t)  for t in range(2))
    m.addConstrs( y1[t]>=0 for t in range(2))
    m.addConstrs( y1[t]<=c[t]-demand[t]+x*((-1)**t)+M*(1-z1[0,t]) for t in range(2))
    m.addConstrs( y1[t]<=M*(1-z2[0,t])  for t in range(2))
    m.addConstrs( z1[0,t]+z2[0,t]>=1 for t in range(2))
    
    m.addConstrs( y2[t]>=-c[t]+demand[t]-x*((-1)**t)  for t in range(2))
    m.addConstrs( y2[t]>=0 for t in range(2))
    m.addConstrs( y2[t]<=-c[t]+demand[t]-x*((-1)**t)+M*(1-z1[1,t]) for t in range(2))
    m.addConstrs( y2[t]<=M*(1-z2[1,t])  for t in range(2))
    m.addConstrs( z1[1,t]+z2[1,t]>=1 for t in range(2))

    
    #m.addConstr( x<=100000 )
    m.addConstr( x>=0 )
    m.addConstr( x<=max(demand[0]-c[0],0) )

    # Supressing the optimization output
    m.setParam( 'OutputFlag', False )

    # Solving the model
    m.optimize()
    
    return m,x

# %%
def flexibility_mode_actual(demand,c,cost_over,cost_under,x_predict):
    ######### Model Set-up ############
    m = Model()
    M=1e20

    #flexibility
    x = m.addVar(vtype=GRB.CONTINUOUS,name = "flexibility")#x
    y1= m.addVars(2,vtype=GRB.CONTINUOUS,name = "y1")
    y2= m.addVars(2,vtype=GRB.CONTINUOUS,name = "y2")
    z1 = m.addVars(2,2,vtype=GRB.BINARY,name='z1')
    z2 = m.addVars(2,2,vtype=GRB.BINARY,name='z2')

    # set objective
    m.setObjective( quicksum((cost_over[t]*y1[t]+cost_under[t]*y2[t]) for t in range(2)), GRB.MINIMIZE)#

    # add constraint
    
    m.addConstrs( y1[t]>=c[t]-demand[t]+x*((-1)**t)  for t in range(2))
    m.addConstrs( y1[t]>=0 for t in range(2))
    m.addConstrs( y1[t]<=c[t]-demand[t]+x*((-1)**t)+M*(1-z1[0,t]) for t in range(2))
    m.addConstrs( y1[t]<=M*(1-z2[0,t])  for t in range(2))
    m.addConstrs( z1[0,t]+z2[0,t]>=1 for t in range(2))
    
    m.addConstrs( y2[t]>=-c[t]+demand[t]-x*((-1)**t)  for t in range(2))
    m.addConstrs( y2[t]>=0 for t in range(2))
    m.addConstrs( y2[t]<=-c[t]+demand[t]-x*((-1)**t)+M*(1-z1[1,t]) for t in range(2))
    m.addConstrs( y2[t]<=M*(1-z2[1,t])  for t in range(2))
    m.addConstrs( z1[1,t]+z2[1,t]>=1 for t in range(2))

    
    #m.addConstr( x<=100000 )
    m.addConstr( x>=0 )
    m.addConstr( x<=max(demand[0]-c[0],0) )
    m.addConstr( x<=x_predict)

    # Supressing the optimization output
    m.setParam( 'OutputFlag', False )

    # Solving the model
    m.optimize()
    
    return m,x

# %%
def outcome(weekday,period,year):
    weekday_x=weekday
    period_x=period
    year_x=year

    SZXUS=data_select(weekday_x,period_x,year_x,'SZX','predict')
    HKUS=data_select(weekday_x,period_x,year_x,'HK','predict')
    
    df2=HKUS.copy()
    df1=SZXUS.copy()

    # continuous distribution (fit)
    mu1,sigma1=st.norm.fit(df1['demand'])
    print('mu and sigma for SZ:', mu1,sigma1)

    mu2,sigma2=st.norm.fit(df2['demand'])
    print('mu and sigma for HK:',mu2,sigma2)
    print('='*50)

    rv1=st.norm(loc=mu1,scale=sigma1)
    xmin1=min(df1['demand'])
    xmax1=max(df1['demand'])
    x1=np.linspace(xmin1,xmax1,10000)

    rv2=st.norm(loc=mu2,scale=sigma2)
    xmin2=min(df2['demand'])
    xmax2=max(df2['demand'])
    x2=np.linspace(xmin2,xmax2,10000)

    #cost
    cost_over=np.array([7.5,5.7])
    cost_under=np.array([9,7.2])

    value1=(cost_over[0]-0)/(cost_over[0]+cost_under[0])
    c_opt0=rv1.ppf(value1)
    print('non flexible capacity for SZ:',c_opt0)

    value2=(cost_over[1]-0)/(cost_over[1]+cost_under[1])
    c_opt1=rv2.ppf(value2)
    print('non flexible capacity for HK:',c_opt1)
    print('='*50)

    #non-flexible system
    ## predicted cost
    d1=SZXUS['demand']
    d2=HKUS['demand']
   
    cost0=0
    cost1=0

    for j in range(len(d1)):
        cost0+=cost_over[0]*max(c_opt0-d1[j],0)+cost_under[0]*max(d1[j]-c_opt0,0)
    for j in range(len(d2)):
        cost1+=cost_over[1]*max(c_opt1-d2[j],0)+cost_under[1]*max(d2[j]-c_opt1,0)
    cost=cost0+cost1

    print('predict cost for SZ:',cost0)
    print('predict cost for HK:',cost1)
    print('predict non-flexible total cost:',cost)
    print('='*50)
    
    ##actual cost
    d11=data_select(weekday_x,period_x,year_x,'SZX','real')
    d12=data_select(weekday_x,period_x,year_x,'HK','real')
    d11_1=d11['demand']
    d12_1=d12['demand']
    cost2=0
    cost3=0

    for j in range(len(d11_1)):
        cost2+=cost_over[0]*max(c_opt0-d11_1[j],0)+cost_under[0]*max(d11_1[j]-c_opt0,0)
    for j in range(len(d12_1)):
        cost3+=cost_over[1]*max(c_opt1-d12_1[j],0)+cost_under[1]*max(d12_1[j]-c_opt1,0)
    cost_1=cost2+cost3

    print('actual cost for SZ:',cost2)
    print('actual cost for HK:',cost3)
    print('actual non-flexible total cost:',cost_1)
    print(cost2)
    print(cost3)
    print('='*50)

    #flexible system
    df21=SZXUS[['date','demand']]
    df21.rename(columns={'demand':'SZX_demand'},inplace=True)
    df22=HKUS[['date','demand']]
    df22.rename(columns={'demand':'HK_demand'},inplace=True)
    df_flex=pd.merge(df21,df22,how='outer',on='date')
    df_flex=df_flex.fillna(0)
    
    c=[c_opt0, c_opt1]
    
    #cost
    cost_over=np.array([7.5,5.7])
    cost_under=np.array([9,7.2])

    ## get predicted flexibility
    demand=np.array(df_flex[['SZX_demand','HK_demand']])
    
    for i in range(len(demand)):
        m,x=flexibility_model(demand[i],c,cost_over,cost_under)
        df_flex.loc[i,'x_predict']=x.x
        if df_flex.loc[i,'SZX_demand']==0:
            df_flex.loc[i,'ojbvalue']=cost_over[1]*max(c[1]-df_flex.loc[i,'HK_demand'],0)+cost_under[1]*max(df_flex.loc[i,'HK_demand']-c[1],0)
            #df_flex.loc[i,'real_cost']=cost_over[1]*max(c[1]-df_flex.loc[i,'HK_demand_real'],0)+cost_under[1]*max(df_flex.loc[i,'HK_demand_real']-c[1],0)
        else :
            df_flex.loc[i,'ojbvalue']=m.objVal
            #df_flex.loc[i,'real_cost']=cost_over[1]*max(c[1]-df_flex.loc[i,'HK_demand_real']-x.x,0)+cost_under[1]*max(df_flex.loc[i,'HK_demand_real']+x.x-c[1],0)\
           # +cost_over[0]*max(c[0]-df_flex.loc[i,'SZX_demand_real']+x.x,0)+cost_under[0]*max(df_flex.loc[i,'SZX_demand_real']-x.x-c[0],0)
    
    ## calculate real flexibility
    df_a=d11[['date','demand']]
    df_a.rename(columns={'demand':'SZX_demand_real'},inplace=True)
    df_b=d12[['date','demand']]
    df_b.rename(columns={'demand':'HK_demand_real'},inplace=True)
    df_flex=pd.merge(df_flex,df_a,how='outer',on='date')
    df_flex=pd.merge(df_flex,df_b,how='outer',on='date')
    df_flex=df_flex.fillna(0)

    #demand1=np.array(df_flex[['SZX_demand_real','HK_demand_real']])
    
    for i in range(len(df_flex)):
        x_predict=df_flex.loc[i,'x_predict']
        demand1=df_flex.loc[i,'SZX_demand_real']
        demand2=df_flex.loc[i,'HK_demand_real']
        demand=[demand1,demand2]
        m,x=flexibility_mode_actual(demand,c,cost_over,cost_under,x_predict)
        df_flex.loc[i,'x_real']=x.x
        if df_flex.loc[i,'SZX_demand_real']==0:
            if df_flex.loc[i,'HK_demand_real']==0:
                df_flex.loc[i,'real_cost']=0
            else:
                df_flex.loc[i,'real_cost']=cost_over[1]*max(c[1]-df_flex.loc[i,'HK_demand_real'],0)+cost_under[1]*max(df_flex.loc[i,'HK_demand_real']-c[1],0)
        else :
            df_flex.loc[i,'real_cost']=m.objVal    
       
    
    obj_cost=df_flex['ojbvalue'].sum()  
    print('predicted flexible obj cost:',obj_cost)
    print('='*50)
    
    real_cost=df_flex['real_cost'].sum()
    print('actual flexible obj cost:',real_cost)
    print('='*50)
    
    print(df_flex)

# %%
#for y in [2020]:
for y in (2019,2020):
    for j in (1,2,3):
        for i in (1,6):
            print('year',y,',period',j,',day',i)
            print(outcome(i,j,y))
            print("="*30,"*"*15,"="*30)
            print("   "*20)
            print("="*30,"*"*15,"="*30)
# Out:
# year 2019 ,period 1 ,day 1
# mu and sigma for SZ: 245055.45454545456 95736.91231263427
# mu and sigma for HK: 495417.3333333333 177741.5123699457
# ==================================================
# non flexible capacity for SZ: 234123.70703561165
# non flexible capacity for HK: 469421.93794890126
# ==================================================
# predict cost for SZ: 6949331.501737222
# predict cost for HK: 11476130.35983741
# predict non-flexible total cost: 18425461.86157463
# ==================================================
# actual cost for SZ: 8373419.501737222
# actual cost for HK: 14241823.458459888
# actual non-flexible total cost: 22615242.96019711
# 8373419.501737222
# 14241823.458459888
# ==================================================
# predicted flexible obj cost: 17568967.24288744
# ==================================================
# actual flexible obj cost: 21150154.49006438
# ==================================================
#           date  SZX_demand  HK_demand      x_predict      ojbvalue  \
# 0   2019-01-07    335161.0   476872.0  101037.292964  7.811090e+05
# 1   2019-01-14    344049.0   510309.0  109925.292964  1.085849e+06
# 2   2019-01-21    350900.0   546986.0  116776.292964  1.399251e+06
# 3   2019-01-28     10390.0   719708.0       0.000000  3.480062e+06
# 4   2019-02-04    145532.0   276723.0       0.000000  1.762822e+06
# 5   2019-02-18    190868.0   358772.0       0.000000  9.551224e+05
# 6   2019-02-25    235198.0   503676.0    1074.292964  2.543642e+05
# 7   2019-03-04    249073.0   598026.0   14949.292964  1.033584e+06
# 8   2019-03-11    262101.0   617137.0   27977.292964  1.264985e+06
# 9   2019-03-18    284475.0   640546.0   50351.292964  1.594623e+06
# 10  2019-03-25    287863.0   638996.0   53739.292964  1.607856e+06
# 11  2019-02-11         0.0    57257.0       0.000000  2.349340e+06
#
#     SZX_demand_real  HK_demand_real         x_real     real_cost
# 0          275263.0        455675.0   41139.292964  1.972250e+05
# 1          285269.0        396620.0   51145.292964  1.234429e+05
# 2          343699.0        542446.0  109575.292964  1.314715e+06
# 3          458132.0        747576.0       0.000000  4.018784e+06
# 4           29327.0         93620.0       0.000000  3.678046e+06
# 5          130787.0        299528.0       0.000000  1.743421e+06
# 6          188140.0        369524.0       0.000000  9.142960e+05
# 7          250482.0        584591.0   14949.292964  9.495332e+05
# 8          269524.0        571383.0   27977.292964  1.002363e+06
# 9          325840.0        681930.0   50351.292964  2.264872e+06
# 10         300063.0        740421.0   53739.292964  2.447916e+06
# 11              0.0         31608.0       0.000000  2.495539e+06
# None
# ============================== *************** ==============================
#
# ============================== *************** ==============================
# year 2019 ,period 1 ,day 6
# mu and sigma for SZ: 431476.9166666667 120979.69508245199
# mu and sigma for HK: 583790.0 197828.36466337333
# ==================================================
# non flexible capacity for SZ: 417662.8145767602
# non flexible capacity for HK: 554856.823449908
# ==================================================
# predict cost for SZ: 9410977.609325701
# predict cost for HK: 14043172.715103865
# predict non-flexible total cost: 23454150.324429564
# ==================================================
# actual cost for SZ: 15063690.118966913
# actual cost for HK: 15653575.537607677
# actual non-flexible total cost: 30717265.656574592
# 15063690.118966913
# 15653575.537607677
# ==================================================
# predicted flexible obj cost: 22291868.855620407
# ==================================================
# actual flexible obj cost: 29554984.187765434
# ==================================================
#           date  SZX_demand  HK_demand      x_predict      ojbvalue  \
# 0   2019-01-05    402192.0   570020.0       0.000000  2.252060e+05
# 1   2019-01-12    603376.0   577927.0  185713.185423  1.503240e+06
# 2   2019-01-19    608722.0   618413.0  191059.185423  1.833231e+06
# 3   2019-01-26    620832.0   747363.0  203169.185423  2.848863e+06
# 4   2019-02-02    277017.0   385331.0       0.000000  2.021141e+06
# 5   2019-02-16    222956.0   381627.0       0.000000  2.447711e+06
# 6   2019-02-23    366439.0   497438.0       0.000000  7.114659e+05
# 7   2019-03-02    370296.0   727316.0       0.000000  1.596957e+06
# 8   2019-03-09    392143.0   720949.0       0.000000  1.387262e+06
# 9   2019-03-16    412654.0   743989.0       0.000000  1.399318e+06
# 10  2019-03-23    447881.0   772209.0   30218.185423  1.782507e+06
# 11  2019-03-30    453215.0   770341.0   35552.185423  1.807462e+06
# 12  2019-02-09         0.0    76347.0       0.000000  2.727506e+06
#
#     SZX_demand_real  HK_demand_real         x_real     real_cost
# 0          616311.0        537985.0       0.000000  1.884003e+06
# 1          662716.0        587483.0  185713.185423  2.106103e+06
# 2          625485.0        618846.0  191059.185423  1.987215e+06
# 3          825152.0        764067.0  203169.185423  4.808011e+06
# 4          170158.0        274179.0       0.000000  3.456150e+06
# 5          332401.0        170867.0       0.000000  2.828206e+06
# 6          375251.0        383701.0       0.000000  1.293677e+06
# 7          414204.0        587629.0       0.000000  2.619008e+05
# 8          464224.0        745155.0       0.000000  1.789198e+06
# 9               0.0        812925.0       0.000000  1.858091e+06
# 10         538807.0        772019.0   30218.185423  2.599473e+06
# 11         549157.0        636424.0   35552.185423  1.706737e+06
# 12              0.0         32713.0       0.000000  2.976220e+06
# None
# ============================== *************** ==============================
#
# ============================== *************** ==============================
# year 2019 ,period 2 ,day 1
# mu and sigma for SZ: 376041.44444444444 147901.21180740462
# mu and sigma for HK: 556873.8888888889 99181.95846069367
# ==================================================
# non flexible capacity for SZ: 359153.30104372004
# non flexible capacity for HK: 542368.1373015967
# ==================================================
# predict cost for SZ: 18876582.518589832
# predict cost for HK: 12662581.947619159
# predict non-flexible total cost: 31539164.46620899
# ==================================================
# actual cost for SZ: 20056330.625246406
# actual cost for HK: 29172859.993331987
# actual non-flexible total cost: 49229190.61857839
# 20056330.625246406
# 29172859.993331987
# ==================================================
# predicted flexible obj cost: 23848795.789905753
# ==================================================
# actual flexible obj cost: 48213077.84421449
# ==================================================
#           date  SZX_demand  HK_demand      x_predict      ojbvalue  \
# 0   2019-04-01    239847.0   524552.0       0.000000  9.963492e+05
# 1   2019-04-08    153697.0   561968.0       0.000000  1.682041e+06
# 2   2019-04-15    305550.0   581410.0       0.000000  6.831262e+05
# 3   2019-04-22    316132.0   508338.0       0.000000  5.166315e+05
# 4   2019-04-29    304857.0   588748.0       0.000000  7.411573e+05
# 5   2019-05-06    344485.0   628954.0       0.000000  7.334305e+05
# 6   2019-05-13    306728.0   564285.0       0.000000  5.509912e+05
# 7   2019-05-20    307515.0   636775.0       0.000000  1.067017e+06
# 8   2019-05-27    425055.0   622398.0   65901.698956  1.050707e+06
# 9   2019-06-03    389181.0   552363.0   30027.698956  2.881624e+05
# 10  2019-06-10    196963.0   458961.0       0.000000  1.691848e+06
# 11  2019-06-17    412547.0   486301.0   53393.698956  1.523860e+04
# 12  2019-06-24    382553.0   503455.0   23399.698956  8.842660e+04
# 13  2019-07-01    371878.0   500059.0   12724.698956  1.686313e+05
# 14  2019-07-08    379961.0   499174.0   20807.698956  1.276027e+05
# 15  2019-07-15    385041.0   470301.0   25887.698956  2.632228e+05
# 16  2019-07-22    376565.0   491316.0   17411.698956  1.917505e+05
# 17  2019-07-29    376552.0   493022.0   17398.698956  1.821004e+05
# 18  2019-08-05    384259.0   479043.0   25105.698956  2.178508e+05
# 19  2019-08-12    412520.0   491802.0   53366.698956  2.016404e+04
# 20  2019-08-19    411642.0   502210.0   52488.698956  8.878004e+04
# 21  2019-08-26    431884.0   510320.0   72730.698956  2.929144e+05
# 22  2019-09-02    439648.0   505852.0   80494.698956  3.166456e+05
# 23  2019-09-09    485007.0   490187.0  125853.698956  5.304424e+05
# 24  2019-09-16    220440.0   713614.0       0.000000  2.273320e+06
# 25  2019-09-23    371249.0   797131.0   12095.698956  1.921382e+06
# 26  2019-09-30   1021363.0   873056.0  662209.698956  7.148862e+06
#
#     SZX_demand_real  HK_demand_real         x_real     real_cost
# 0          326277.0        699369.0       0.000000  1.376978e+06
# 1          153928.0        422544.0       0.000000  2.222187e+06
# 2          300763.0        710606.0       0.000000  1.649240e+06
# 3          307188.0        312949.0       0.000000  1.697429e+06
# 4          548204.0        757658.0       0.000000  3.251543e+06
# 5          424746.0        465160.0       0.000000  1.030421e+06
# 6          285313.0        746188.0       0.000000  2.021305e+06
# 7          354856.0        787220.0       0.000000  1.795163e+06
# 8          285222.0        730854.0       0.000000  1.911583e+06
# 9          282344.0        762015.0       0.000000  2.157527e+06
# 10         200343.0        578371.0       0.000000  1.450298e+06
# 11         312284.0        845895.0       0.000000  2.536913e+06
# 12         295159.0        791373.0       0.000000  2.272792e+06
# 13         268795.0        701380.0       0.000000  1.822573e+06
# 14         262323.0        685879.0       0.000000  1.759505e+06
# 15         271657.0        631752.0       0.000000  1.299786e+06
# 16         273296.0        555267.0       0.000000  7.368016e+05
# 17         279599.0        687226.0       0.000000  1.639634e+06
# 18         313315.0        578081.0       0.000000  6.009199e+05
# 19         325151.0        611687.0       0.000000  7.541131e+05
# 20         343571.0        637341.0       0.000000  8.006719e+05
# 21         409454.0        723474.0   50300.698956  1.666127e+06
# 22         289843.0        641589.0       0.000000  1.234217e+06
# 23         294726.0        642361.0       0.000000  1.203153e+06
# 24         188508.0        304791.0       0.000000  2.634029e+06
# 25         374820.0        758045.0   12095.698956  1.672101e+06
# 26         861264.0        736933.0  502110.698956  5.016064e+06
# None
# ============================== *************** ==============================
#
# ============================== *************** ==============================
# year 2019 ,period 2 ,day 6
# mu and sigma for SZ: 567403.9565217391 55711.360900923006
# mu and sigma for HK: 688168.2307692308 119212.25711932984
# ==================================================
# non flexible capacity for SZ: 561042.53838022
# non flexible capacity for HK: 670732.9692078378
# ==================================================
# predict cost for SZ: 9200075.654578019
# predict cost for HK: 15141756.803228274
# predict non-flexible total cost: 24341832.457806293
# ==================================================
# actual cost for SZ: 14070236.0757033
# actual cost for HK: 17055127.808790483
# actual non-flexible total cost: 31125363.884493783
# 14070236.0757033
# 17055127.808790483
# ==================================================
# predicted flexible obj cost: 21848583.25026805
# ==================================================
# actual flexible obj cost: 29616719.448503904
# ==================================================
#           date  SZX_demand  HK_demand     x_predict      ojbvalue  \
# 0   2019-04-13    556095.0   702173.0       0.00000  2.634748e+05
# 1   2019-04-20    616640.0   462400.0   55597.46162  8.705924e+05
# 2   2019-04-27    637997.0   800656.0   76954.46162  1.489518e+06
# 3   2019-05-04    615242.0   801116.0   54199.46162  1.328994e+06
# 4   2019-05-11    695217.0   776970.0  134174.46162  1.730963e+06
# 5   2019-05-18    619017.0   779216.0   57974.46162  1.198494e+06
# 6   2019-05-25    620607.0   786631.0   59564.46162  1.263330e+06
# 7   2019-06-01    560887.0   797529.0       0.00000  9.140980e+05
# 8   2019-06-15    601803.0   648096.0   40760.46162  1.304891e+05
# 9   2019-06-22    544384.0   686628.0       0.00000  2.393833e+05
# 10  2019-06-29    504805.0   712134.0       0.00000  7.198690e+05
# 11  2019-07-06    490717.0   646656.0       0.00000  6.646803e+05
# 12  2019-07-13    501384.0   685444.0       0.00000  5.533585e+05
# 13  2019-07-20    508086.0   645797.0       0.00000  5.393091e+05
# 14  2019-07-27    496902.0   629250.0       0.00000  7.175070e+05
# 15  2019-08-03    496885.0   631434.0       0.00000  7.051857e+05
# 16  2019-08-10    507055.0   613531.0       0.00000  7.309578e+05
# 17  2019-08-17    544348.0   629872.0       0.00000  3.581166e+05
# 18  2019-08-24    543189.0   643202.0       0.00000  2.908281e+05
# 19  2019-08-31    569900.0   653589.0    8857.46162  4.723309e+04
# 20  2019-09-07    580144.0   647866.0   19101.46162  2.146339e+04
# 21  2019-09-21    618870.0   868426.0   57827.46162  1.839748e+06
# 22  2019-09-28    620117.0  1025955.0   59074.46162  2.982935e+06
# 23  2019-04-06         0.0   614322.0       0.00000  3.215425e+05
# 24  2019-06-08         0.0   441218.0       0.00000  1.308235e+06
# 25  2019-09-14         0.0   562263.0       0.00000  6.182788e+05
#
#     SZX_demand_real  HK_demand_real       x_real     real_cost
# 0          558729.0        710446.0      0.00000  3.032854e+05
# 1          561078.0        629940.0     35.46162  2.323178e+05
# 2          579661.0        712444.0  18618.46162  4.343723e+05
# 3          221807.0        330436.0      0.00000  4.483959e+06
# 4          550379.0        741296.0      0.00000  5.880304e+05
# 5          538091.0        756197.0      0.00000  7.874776e+05
# 6          623377.0        727999.0  59564.46162  8.661095e+05
# 7          495442.0        716971.0      0.00000  8.249179e+05
# 8          523902.0        661610.0      0.00000  3.305550e+05
# 9          547021.0        701118.0      0.00000  3.239338e+05
# 10         551299.0        711215.0      0.00000  3.645472e+05
# 11         530012.0        681854.0      0.00000  3.128005e+05
# 12         512748.0        634030.0      0.00000  5.714160e+05
# 13         575981.0        617109.0      0.00000  4.401028e+05
# 14         567808.0        565044.0      0.00000  6.633163e+05
# 15         484719.0        607650.0      0.00000  9.319995e+05
# 16         554213.0        617869.0      0.00000  3.525462e+05
# 17         544708.0        573237.0      0.00000  6.782361e+05
# 18         564858.0        541755.0      0.00000  7.695136e+05
# 19         588754.0        637310.0   8857.46162  3.097094e+05
# 20         595018.0        595687.0  19101.46162  4.527497e+05
# 21         727377.0        556791.0  57827.46162  1.296416e+06
# 22         791745.0        671113.0  59074.46162  1.972724e+06
# 23              0.0        273648.0      0.00000  2.263384e+06
# 24              0.0        228007.0      0.00000  2.523538e+06
# 25          43772.0        204201.0      0.00000  6.538761e+06
# None
# ============================== *************** ==============================
#
# ============================== *************** ==============================
# year 2019 ,period 3 ,day 1
# mu and sigma for SZ: 478748.9166666667 84154.16443791155
# mu and sigma for HK: 762106.8461538461 164505.7480425935
# ==================================================
# non flexible capacity for SZ: 469139.7486319499
# non flexible capacity for HK: 738047.2333691961
# ==================================================
# predict cost for SZ: 8048206.909885279
# predict cost for HK: 11634045.698493766
# predict non-flexible total cost: 19682252.608379044
# ==================================================
# actual cost for SZ: 7717139.934333594
# actual cost for HK: 12170654.777568506
# actual non-flexible total cost: 19887794.7119021
# 7717139.934333594
# 12170654.777568506
# ==================================================
# predicted flexible obj cost: 18636723.99849377
# ==================================================
# actual flexible obj cost: 19743633.60697712
# ==================================================
#           date  SZX_demand  HK_demand      x_predict      ojbvalue  \
# 0   2019-10-14    374052.0   643353.0       0.000000  1.252915e+06
# 1   2019-10-21    382281.0   717718.0       0.000000  7.673172e+05
# 2   2019-10-28    378191.0   758882.0       0.000000  8.321259e+05
# 3   2019-11-04    377295.0   820709.0       0.000000  1.284000e+06
# 4   2019-11-11    554677.0   871050.0   85537.251368  1.573488e+06
# 5   2019-11-18    531543.0   876667.0   62403.251368  1.447366e+06
# 6   2019-11-25    560232.0   886683.0   91092.251368  1.726042e+06
# 7   2019-12-02    577296.0   938560.0  108156.251368  2.222417e+06
# 8   2019-12-09    576920.0   913690.0  107780.251368  2.040646e+06
# 9   2019-12-16    548680.0   852588.0   79540.251368  1.397383e+06
# 10  2019-12-23    409006.0   763663.0       0.000000  6.354366e+05
# 11  2019-12-30    474814.0   507478.0    5674.251368  1.281901e+06
# 12  2019-10-07         0.0   356348.0       0.000000  2.175686e+06
#
#     SZX_demand_real  HK_demand_real        x_real     real_cost
# 0          430584.0        848902.0      0.000000  1.087322e+06
# 1          385407.0        837012.0      0.000000  1.340542e+06
# 2          471619.0        898395.0      0.000000  1.176817e+06
# 3          448114.0        741752.0      0.000000  1.843674e+05
# 4          404537.0        907832.0      0.000000  1.706971e+06
# 5          514404.0       1006177.0  45264.251368  2.256437e+06
# 6          437634.0        881977.0      0.000000  1.272587e+06
# 7          503965.0        899935.0  34825.251368  1.416334e+06
# 8          425564.0        758267.0      0.000000  4.724004e+05
# 9          424756.0        877171.0      0.000000  1.334569e+06
# 10         417898.0        786394.0      0.000000  7.324098e+05
# 11         292626.0        689805.0      0.000000  1.598834e+06
# 12          94408.0        325143.0      0.000000  5.164042e+06
# None
# ============================== *************** ==============================
#
# ============================== *************** ==============================
# year 2019 ,period 3 ,day 6
# mu and sigma for SZ: 686766.9166666666 65160.21759409435
# mu and sigma for HK: 830049.9230769231 147238.49024598548
# ==================================================
# non flexible capacity for SZ: 679326.5780426366
# non flexible capacity for HK: 808515.7146710402
# ==================================================
# predict cost for SZ: 5842753.7599127665
# predict cost for HK: 9926971.045303477
# predict non-flexible total cost: 15769724.805216243
# ==================================================
# actual cost for SZ: 16796621.44441852
# actual cost for HK: 8535768.399354823
# actual non-flexible total cost: 25332389.843773343
# 16796621.44441852
# 8535768.399354823
# ==================================================
# predicted flexible obj cost: 15059282.888553467
# ==================================================
# actual flexible obj cost: 23206660.802097753
# ==================================================
#           date  SZX_demand  HK_demand     x_predict      ojbvalue  \
# 0   2019-10-12    730326.0   809575.0  50999.421957  3.748227e+05
# 1   2019-10-19    638506.0   873901.0      0.000000  7.769284e+05
# 2   2019-10-26    627978.0   899729.0      0.000000  1.041850e+06
# 3   2019-11-02    633854.0   906713.0      0.000000  1.048065e+06
# 4   2019-11-09    651184.0   916192.0      0.000000  9.863386e+05
# 5   2019-11-16    731923.0   877758.0  52596.421957  8.772387e+05
# 6   2019-11-23    701399.0   883417.0  22072.421957  6.982107e+05
# 7   2019-11-30    739263.0   893512.0  59936.421957  1.043515e+06
# 8   2019-12-07    761780.0   945945.0  82453.421957  1.583155e+06
# 9   2019-12-14    761275.0   920881.0  81948.421957  1.399059e+06
# 10  2019-12-21    724010.0   859279.0  44683.421957  6.872163e+05
# 11  2019-12-28    539705.0   586274.0      0.000000  2.313940e+06
# 12  2019-10-05         0.0   417473.0      0.000000  2.228943e+06
#
#     SZX_demand_real  HK_demand_real        x_real     real_cost
# 0          744959.0        702378.0  50999.421957  4.459853e+05
# 1          706073.0        700736.0      0.000000  8.550622e+05
# 2          753441.0        705585.0      0.000000  1.253735e+06
# 3          765638.0        673714.0      0.000000  1.545173e+06
# 4          843779.0        771264.0      0.000000  1.692407e+06
# 5          870406.0        848760.0  52596.421957  1.914800e+06
# 6          828780.0        703572.0  22072.421957  1.618795e+06
# 7          717854.0        807065.0  38527.421957  2.669523e+05
# 8          740002.0        815523.0  60675.421957  4.873155e+05
# 9          900516.0        879844.0  81948.421957  2.356761e+06
# 10         896623.0        767300.0  44683.421957  1.578484e+06
# 11         612062.0        676420.0      0.000000  1.257430e+06
# 12          61616.0        229405.0      0.000000  7.933760e+06
# None
# ============================== *************** ==============================
#
# ============================== *************** ==============================
# year 2020 ,period 1 ,day 1
# mu and sigma for SZ: 356118.4166666667 110042.22914216339
# mu and sigma for HK: 548393.6153846154 276511.4964649998
# ==================================================
# non flexible capacity for SZ: 343553.2123442827
# non flexible capacity for HK: 507952.7212844925
# ==================================================
# predict cost for SZ: 8314387.088901456
# predict cost for HK: 20889492.306051314
# predict non-flexible total cost: 29203879.39495277
# ==================================================
# actual cost for SZ: 13972152.503680665
# actual cost for HK: 23814699.403869614
# actual non-flexible total cost: 37786851.907550275
# 13972152.503680665
# 23814699.403869614
# ==================================================
# predicted flexible obj cost: 28173487.888271026
# ==================================================
# actual flexible obj cost: 37309530.85420941
# ==================================================
#           date  SZX_demand  HK_demand      x_predict      ojbvalue  \
# 0   2020-01-06    470294.0   586956.0  126740.787656  1.481357e+06
# 1   2020-01-13    510656.0   759154.0  167102.787656  3.011789e+06
# 2   2020-01-20    535898.0   932817.0  192344.787656  4.443905e+06
# 3   2020-02-03    128440.0    50159.0       0.000000  4.222773e+06
# 4   2020-02-10    227839.0   231256.0       0.000000  2.445028e+06
# 5   2020-02-17    288731.0   389330.0       0.000000  1.087316e+06
# 6   2020-02-24    333609.0   545983.0       0.000000  3.483996e+05
# 7   2020-03-02    340047.0   677789.0       0.000000  1.249118e+06
# 8   2020-03-09    356971.0   752716.0   13417.787656  1.858904e+06
# 9   2020-03-16    372840.0   778031.0   29286.787656  2.155428e+06
# 10  2020-03-23    387100.0   760449.0   43546.787656  2.131510e+06
# 11  2020-03-30    320996.0   629320.0       0.000000  1.043023e+06
# 12  2020-01-27         0.0    35157.0       0.000000  2.694936e+06
#
#     SZX_demand_real  HK_demand_real         x_real     real_cost
# 0          334737.0        563228.0       0.000000  4.641036e+05
# 1          306893.0        642239.0       0.000000  1.241813e+06
# 2          619007.0       1000038.0  192344.787656  5.675877e+06
# 3            5108.0         44007.0       0.000000  5.182830e+06
# 4               0.0         43878.0       0.000000  2.645226e+06
# 5          118997.0        210763.0       0.000000  3.378153e+06
# 6          208147.0        312583.0       0.000000  2.129154e+06
# 7          255694.0        445441.0       0.000000  1.015261e+06
# 8          310647.0        760916.0       0.000000  2.068132e+06
# 9          507063.0        781653.0   29286.787656  3.389514e+06
# 10         466407.0        796705.0   43546.787656  3.106316e+06
# 11         613656.0       1144373.0       0.000000  7.013151e+06
# 12              0.0             0.0       0.000000  0.000000e+00
# None
# ============================== *************** ==============================
#
# ============================== *************** ==============================
# year 2020 ,period 1 ,day 6
# mu and sigma for SZ: 429107.0 172470.6209933545
# mu and sigma for HK: 539268.1538461539 264275.7389140965
# ==================================================
# non flexible capacity for SZ: 409413.3913800743
# non flexible capacity for HK: 500616.78742092644
# ==================================================
# predict cost for SZ: 14145816.06203688
# predict cost for HK: 20492295.786051046
# predict non-flexible total cost: 34638111.84808792
# ==================================================
# actual cost for SZ: 22995610.691335768
# actual cost for HK: 21707368.38605104
# actual non-flexible total cost: 44702979.07738681
# 22995610.691335768
# 21707368.38605104
# ==================================================
# predicted flexible obj cost: 32901576.48396099
# ==================================================
# actual flexible obj cost: 42966443.713259876
# ==================================================
#           date  SZX_demand  HK_demand     x_predict      ojbvalue  \
# 0   2020-01-04    582898.0   763910.0  173484.60862  3.144800e+06
# 1   2020-01-11    620577.0   775168.0  211163.60862  3.497147e+06
# 2   2020-01-18    673837.0   945299.0  264423.60862  5.105562e+06
# 3   2020-02-01     58120.0   130935.0       0.00000  4.741887e+06
# 4   2020-02-08    169479.0   157414.0       0.00000  3.755764e+06
# 5   2020-02-15    300643.0   325423.0       0.00000  1.814383e+06
# 6   2020-02-22    380993.0   409434.0       0.00000  7.328948e+05
# 7   2020-02-29    440212.0   504204.0   30798.60862  2.475779e+05
# 8   2020-03-07    448708.0   625844.0   39294.60862  1.184557e+06
# 9   2020-03-14    471040.0   694993.0   61626.60862  1.843220e+06
# 10  2020-03-21    491980.0   718355.0   82566.60862  2.162195e+06
# 11  2020-03-28    510797.0   787732.0  101383.60862  2.797192e+06
# 12  2020-01-25         0.0   171775.0       0.00000  1.874398e+06
#
#     SZX_demand_real  HK_demand_real        x_real     real_cost
# 0          666262.0        581541.0  173484.60862  2.582020e+06
# 1          636540.0        580701.0  211163.60862  2.240651e+06
# 2          761227.0        852348.0  264423.60862  5.222825e+06
# 3               0.0         25990.0       0.00000  2.705373e+06
# 4               0.0        122566.0       0.00000  2.154889e+06
# 5          142999.0        285535.0       0.00000  3.224074e+06
# 6          284773.0        265936.0       0.00000  2.272483e+06
# 7          594572.0        633596.0   30798.60862  2.568440e+06
# 8          640618.0        634969.0   39294.60862  2.977447e+06
# 9          641633.0        769470.0   61626.60862  3.914792e+06
# 10         660714.0        666590.0   82566.60862  3.308093e+06
# 11         902930.0        874114.0  101383.60862  6.948339e+06
# 12              0.0          1140.0       0.00000  2.847018e+06
# None
# ============================== *************** ==============================
#
# ============================== *************** ==============================
# year 2020 ,period 2 ,day 1
# mu and sigma for SZ: 379348.25 57936.95203426595
# mu and sigma for HK: 594028.8461538461 128579.63772777983
# ==================================================
# non flexible capacity for SZ: 372732.70207988087
# non flexible capacity for HK: 575223.5683290252
# ==================================================
# predict cost for SZ: 8732784.446880177
# predict cost for HK: 16185265.460361885
# predict non-flexible total cost: 24918049.90724206
# ==================================================
# actual cost for SZ: 21068654.94097197
# actual cost for HK: 45426148.57169533
# actual non-flexible total cost: 66494803.5126673
# 21068654.94097197
# 45426148.57169533
# ==================================================
# predicted flexible obj cost: 23789945.77697928
# ==================================================
# actual flexible obj cost: 65709014.62261759
# ==================================================
#           date  SZX_demand  HK_demand     x_predict      ojbvalue  \
# 0   2020-04-13    302610.0   338160.0       0.00000  1.877183e+06
# 1   2020-04-20    313796.0   569416.0       0.00000  4.751284e+05
# 2   2020-04-27    362955.0   700870.0       0.00000  9.779871e+05
# 3   2020-05-11    342086.0   727397.0       0.00000  1.325499e+06
# 4   2020-05-18    326040.0   735294.0       0.00000  1.502702e+06
# 5   2020-05-25    365263.0   751277.0       0.00000  1.323607e+06
# 6   2020-06-01    388952.0   707401.0   16219.29792  1.068456e+06
# 7   2020-06-08    389974.0   688898.0   17241.29792  9.425933e+05
# 8   2020-06-15    406096.0   690313.0   33363.29792  1.068860e+06
# 9   2020-06-22    425383.0   753933.0   52650.29792  1.665790e+06
# 10  2020-06-29    429806.0   656876.0   57073.29792  9.988253e+05
# 11  2020-07-06    322114.0   614735.0       0.00000  6.641226e+05
# 12  2020-07-13    311471.0   578150.0       0.00000  4.805331e+05
# 13  2020-07-20    370718.0   594974.0       0.00000  1.573134e+05
# 14  2020-07-27    366883.0   603021.0       0.00000  2.440143e+05
# 15  2020-08-03    366694.0   555036.0       0.00000  1.603594e+05
# 16  2020-08-10    387994.0   571694.0   15261.29792  8.446845e+04
# 17  2020-08-17    396957.0   593699.0   24224.29792  3.074381e+05
# 18  2020-08-24    413033.0   638487.0   40300.29792  7.456589e+05
# 19  2020-08-31    439171.0   600849.0   66438.29792  6.628589e+05
# 20  2020-09-07    459578.0   597270.0   86845.29792  7.840205e+05
# 21  2020-09-14    313490.0   524539.0       0.00000  7.332223e+05
# 22  2020-09-21    338749.0   526247.0       0.00000  5.340442e+05
# 23  2020-09-28    564545.0   591294.0  191812.29792  1.496756e+06
# 24  2020-04-06         0.0   296678.0       0.00000  1.587710e+06
# 25  2020-05-04         0.0   238242.0       0.00000  1.920795e+06
#
#     SZX_demand_real  HK_demand_real        x_real     real_cost
# 0          230656.0        815230.0       0.00000  2.793622e+06
# 1          438073.0        713930.0       0.00000  1.586749e+06
# 2          541591.0        839072.0       0.00000  3.419433e+06
# 3          666338.0        953152.0       0.00000  5.363532e+06
# 4          391028.0        599759.0       0.00000  3.413128e+05
# 5          344030.0        807136.0       0.00000  1.885040e+06
# 6          426502.0        767139.0   16219.29792  1.836520e+06
# 7          449853.0       1075785.0   17241.29792  4.267091e+06
# 8          468016.0        844043.0   33363.29792  2.732996e+06
# 9          465276.0       1341161.0   52650.29792  6.252869e+06
# 10         706157.0        896730.0   57073.29792  5.212933e+06
# 11         490906.0        901059.0       0.00000  3.409575e+06
# 12         443966.0        931482.0       0.00000  3.206160e+06
# 13         350965.0        914628.0       0.00000  2.606970e+06
# 14         422188.0        799563.0       0.00000  2.060342e+06
# 15         235553.0        544724.0       0.00000  1.202695e+06
# 16         265336.0        759794.0       0.00000  2.134382e+06
# 17         361795.0        860483.0       0.00000  2.135901e+06
# 18         429792.0        861356.0   40300.29792  2.501147e+06
# 19         365572.0        647033.0       0.00000  5.707332e+05
# 20         400622.0        596476.0   27889.29792  3.538205e+05
# 21         379705.0        742600.0       0.00000  1.267861e+06
# 22         421416.0        811093.0       0.00000  2.136410e+06
# 23         756637.0        776900.0  191812.29792  4.561947e+06
# 24              0.0        381663.0       0.00000  1.103295e+06
# 25              0.0        681568.0       0.00000  7.656799e+05
# None
# ============================== *************** ==============================
#
# ============================== *************** ==============================
# year 2020 ,period 2 ,day 6
# mu and sigma for SZ: 565143.875 106143.35608871636
# mu and sigma for HK: 628317.6538461539 110386.86222377617
# ==================================================
# non flexible capacity for SZ: 553023.8646447457
# non flexible capacity for HK: 612173.1410056122
# ==================================================
# predict cost for SZ: 16862458.70303288
# predict cost for HK: 12971650.355528578
# predict non-flexible total cost: 29834109.05856146
# ==================================================
# actual cost for SZ: 74757117.77001151
# actual cost for HK: 37223611.61758378
# actual non-flexible total cost: 111980729.3875953
# 74757117.77001151
# 37223611.61758378
# ==================================================
# predicted flexible obj cost: 26905005.65955502
# ==================================================
# actual flexible obj cost: 110154744.53222834
# ==================================================
#           date  SZX_demand  HK_demand      x_predict      ojbvalue  \
# 0   2020-04-04    406229.0   619535.0       0.000000  1.153967e+06
# 1   2020-04-11    639951.0   546160.0   86927.135355  1.505808e+05
# 2   2020-04-18    615337.0   615936.0   62313.135355  4.757472e+05
# 3   2020-04-25    636858.0   684705.0   83834.135355  1.125835e+06
# 4   2020-05-09    696275.0   691893.0  143251.135355  1.605391e+06
# 5   2020-05-16    683771.0   712350.0  130747.135355  1.662653e+06
# 6   2020-05-23    602035.0   720335.0   49011.135355  1.131646e+06
# 7   2020-05-30    481989.0   735866.0       0.000000  1.423350e+06
# 8   2020-06-06    513249.0   720627.0       0.000000  1.079179e+06
# 9   2020-06-13    514598.0   701778.0       0.000000  9.333490e+05
# 10  2020-06-20    535872.0   749437.0       0.000000  1.116939e+06
# 11  2020-07-04    567158.0   725280.0   14134.135355  9.161352e+05
# 12  2020-07-11    425050.0   626229.0       0.000000  1.061006e+06
# 13  2020-07-18    411007.0   588960.0       0.000000  1.197441e+06
# 14  2020-07-25    489187.0   606099.0       0.000000  5.133991e+05
# 15  2020-08-01    484127.0   595607.0       0.000000  6.111535e+05
# 16  2020-08-08    483877.0   593952.0       0.000000  6.224620e+05
# 17  2020-08-15    511985.0   611777.0       0.000000  3.100495e+05
# 18  2020-08-22    523810.0   635324.0       0.000000  3.857902e+05
# 19  2020-08-29    545025.0   683252.0       0.000000  5.717593e+05
# 20  2020-09-05    579515.0   684294.0   26491.135355  7.100064e+05
# 21  2020-09-12    606444.0   639147.0   53420.135355  5.788368e+05
# 22  2020-09-19    773874.0   631051.0  220850.135355  1.726042e+06
# 23  2020-09-26    836230.0   633106.0  283206.135355  2.189801e+06
# 24  2020-05-02         0.0   298685.0       0.000000  1.786882e+06
# 25  2020-06-27         0.0   284874.0       0.000000  1.865605e+06
#
#     SZX_demand_real  HK_demand_real         x_real     real_cost
# 0          625852.0        946804.0       0.000000  3.064795e+06
# 1          584559.0        610375.0   31535.135355  2.141064e+05
# 2          601927.0        875154.0   48903.135355  2.245565e+06
# 3          489746.0        773092.0       0.000000  1.633200e+06
# 4         1100060.0       1046288.0  143251.135355  7.791100e+06
# 5          690400.0        652345.0  130747.135355  1.290278e+06
# 6          815878.0        919214.0   49011.135355  4.488161e+06
# 7          961702.0        896014.0       0.000000  5.721757e+06
# 8         1089825.0       1054457.0       0.000000  8.015654e+06
# 9         1246490.0        563774.0       0.000000  6.517070e+06
# 10        1296677.0        593120.0       0.000000  6.801481e+06
# 11         987239.0       1073221.0   14134.135355  7.202039e+06
# 12         967378.0        869960.0       0.000000  5.585253e+06
# 13         770997.0        742654.0       0.000000  2.901220e+06
# 14         874240.0        951608.0       0.000000  5.334876e+06
# 15         638124.0        574305.0       0.000000  9.817496e+05
# 16         534976.0        567104.0       0.000000  3.922531e+05
# 17         787698.0        730484.0       0.000000  2.963905e+06
# 18         925679.0        880344.0       0.000000  5.284726e+06
# 19        1015008.0        762713.0       0.000000  5.241744e+06
# 20        1092178.0        744039.0   26491.135355  5.754137e+06
# 21        1044391.0        779463.0   53420.135355  5.530635e+06
# 22        1106808.0        877993.0  220850.135355  6.500430e+06
# 23        1181990.0        888181.0  283206.135355  7.138181e+06
# 24              0.0        544689.0       0.000000  3.846596e+05
# 25              0.0        775474.0       0.000000  1.175766e+06
# None
# ============================== *************** ==============================
#
# ============================== *************** ==============================
# year 2020 ,period 3 ,day 1
# mu and sigma for SZ: 438679.3333333333 146383.53623349254
# mu and sigma for HK: 564605.25 37932.82761919417
# ==================================================
# non flexible capacity for SZ: 421964.4861647005
# non flexible capacity for HK: 559057.4247403721
# ==================================================
# predict cost for SZ: 3312136.416988203
# predict cost for HK: 883723.4257788836
# predict non-flexible total cost: 4195859.842767087
# ==================================================
# actual cost for SZ: 678881.9169882028
# actual cost for HK: 7751336.846628084
# actual non-flexible total cost: 8430218.763616286
# 678881.9169882028
# 7751336.846628084
# ==================================================
# predicted flexible obj cost: 3793508.5178635474
# ==================================================
# actual flexible obj cost: 8430218.763616286
# ==================================================
#          date  SZX_demand  HK_demand      x_predict      ojbvalue  \
# 0  2020-10-12    645493.0   576727.0  223528.513835  1.736626e+06
# 1  2020-10-19    343228.0   619699.0       0.000000  1.027143e+06
# 2  2020-10-26    327317.0   543535.0       0.000000  7.983340e+05
# 3  2020-10-05         0.0   518460.0       0.000000  2.314053e+05
#
#    SZX_demand_real  HK_demand_real  x_real     real_cost
# 0         363652.0        730763.0     0.0  1.673624e+06
# 1         415290.0       1074011.0     0.0  3.757724e+06
# 2         443240.0        680569.0     0.0  1.066363e+06
# 3              0.0        220021.0     0.0  1.932508e+06
# None
# ============================== *************** ==============================
#
# ============================== *************** ==============================
# year 2020 ,period 3 ,day 6
# mu and sigma for SZ: 691886.0 199366.04140123763
# mu and sigma for HK: 573940.0 201721.20500210184
# ==================================================
# non flexible capacity for SZ: 669121.3298849016
# non flexible capacity for HK: 544437.4802366969
# ==================================================
# predict cost for SZ: 4882723.036208533
# predict cost for HK: 4871563.36423652
# predict non-flexible total cost: 9754286.400445051
# ==================================================
# actual cost for SZ: 4270384.97930941
# actual cost for HK: 7557296.86423652
# actual non-flexible total cost: 11827681.843545929
# 4270384.97930941
# 7557296.86423652
# ==================================================
# predicted flexible obj cost: 9165748.788030697
# ==================================================
# actual flexible obj cost: 11559840.637338754
# ==================================================
#          date  SZX_demand  HK_demand      x_predict      ojbvalue  \
# 0  2020-10-10    410450.0   623739.0       0.000000  2.511006e+06
# 1  2020-10-17    817922.0   693832.0  148800.670115  2.147005e+06
# 2  2020-10-24    847286.0   745526.0  178164.670115  2.730623e+06
# 3  2020-10-03         0.0   232663.0       0.000000  1.777115e+06
#
#    SZX_demand_real  HK_demand_real         x_real     real_cost
# 0         590654.0        806541.0       0.000000  2.475650e+06
# 1        1069658.0        890776.0  148800.670115  5.830626e+06
# 2         658848.0        770029.0       0.000000  1.701309e+06
# 3              0.0        272112.0       0.000000  1.552255e+06
# None
# ============================== *************** ==============================
#
# ============================== *************** ==============================
