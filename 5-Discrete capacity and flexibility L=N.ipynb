# %%
import pandas as pd
import numpy as np
from gurobipy import *

import warnings
warnings.filterwarnings("ignore")

data = pd.read_csv('demand_ups.csv')

# %%
#We just select SZX-US and HK-US two lanes
#input: 1,3,SZX/US,(default:2019),predict/real

# eg. df=data_select(1,3,2019,'SZX','predict')

lane_dict={'SZX':'SCN-SZX HUB (US)','HK':'HK HUB (US)'}
type_dict={'predict':'predict_d','real':'real_d'}

def data_select(weekday,period,year,lane,datatype='predict'):   
    df=data[(data['Lane']==lane_dict[lane]) & (data['weekday']==weekday) 
            &(data['period']==period) &(data['year']==year)]
    column=['Lane', 'date',type_dict[datatype] ,'weekday', 'month', 'year',
       'quarter', 'period']
    df=df[column]
    df=df[(df[type_dict[datatype]]>=1000)]
    df.reset_index(drop=True,inplace=True)
    df=df.rename(columns={type_dict[datatype]:'demand'})
    return df

# %%
df=data_select(1,2,2019,'SZX','predict')

# %%
df.head()
# Out:
#                Lane        date    demand  weekday  month    year  quarter  \
# 0  SCN-SZX HUB (US)  2019-04-01  239847.0      1.0    4.0  2019.0     23.0
# 1  SCN-SZX HUB (US)  2019-04-08  153697.0      1.0    4.0  2019.0     23.0
# 2  SCN-SZX HUB (US)  2019-04-15  305550.0      1.0    4.0  2019.0     23.0
# 3  SCN-SZX HUB (US)  2019-04-22  316132.0      1.0    4.0  2019.0     23.0
# 4  SCN-SZX HUB (US)  2019-04-29  304857.0      1.0    4.0  2019.0     23.0
#
#    period
# 0     2.0
# 1     2.0
# 2     2.0
# 3     2.0
# 4     2.0

# %%
def weighted_cluster_model(demand,weight,cost_over,cost_under):
    ######### Parameters Set-up ############
    n=len(demand)
    M=1e20
    ######### Model Set-up ############
    m = Model()
    #capacity
    c = m.addVar(vtype=GRB.CONTINUOUS,name = "capacity")#c23
    y1= m.addVars(n,vtype=GRB.CONTINUOUS,name = "y1")
    y2= m.addVars(n,vtype=GRB.CONTINUOUS,name = "y2")
    z1 = m.addVars(n,2,vtype=GRB.BINARY,name='z1')
    z2 = m.addVars(n,2,vtype=GRB.BINARY,name='z2')
    

    # set objective
    m.setObjective( quicksum((cost_over*y1[i]+cost_under*y2[i])*weight[i] for i in range(n)), GRB.MINIMIZE)#

    # add constraint
    m.addConstrs( y1[i]>=c-demand[i] for i in range(n))
    m.addConstrs( y1[i]>=0 for i in range(n))
    m.addConstrs( y1[i]<=c-demand[i]+M*(1-z1[i,0]) for i in range(n))
    m.addConstrs( y1[i]<=M*(1-z2[i,0]) for i in range(n))
    m.addConstrs( z1[i,0]+z2[i,0]>=1 for i in range(n))
    
    m.addConstrs( y2[i]>=-c+demand[i] for i in range(n))
    m.addConstrs( y2[i]>=0 for i in range(n))
    m.addConstrs( y2[i]<=-c+demand[i]+M*(1-z1[i,1]) for i in range(n))
    m.addConstrs( y2[i]<=M*(1-z2[i,1]) for i in range(n))
    m.addConstrs( z1[i,1]+z2[i,1]>=1 for i in range(n))
    

    # Supressing the optimization output
    m.setParam( 'OutputFlag', False )

    # Solving the model
    m.optimize()
    
    return m,c

# %%
def flexibility_model(demand,c,cost_over,cost_under):
    ######### Model Set-up ############
    m = Model()
    M=1e20

    #flexibility
    x = m.addVar(vtype=GRB.CONTINUOUS,name = "flexibility")#x
    y1= m.addVars(2,vtype=GRB.CONTINUOUS,name = "y1")
    y2= m.addVars(2,vtype=GRB.CONTINUOUS,name = "y2")
    z1 = m.addVars(2,2,vtype=GRB.BINARY,name='z1')
    z2 = m.addVars(2,2,vtype=GRB.BINARY,name='z2')

    # set objective
    m.setObjective( quicksum((cost_over[t]*y1[t]+cost_under[t]*y2[t]) for t in range(2)), GRB.MINIMIZE)#

    # add constraint
    
    m.addConstrs( y1[t]>=c[t]-demand[t]+x*((-1)**t)  for t in range(2))
    m.addConstrs( y1[t]>=0 for t in range(2))
    m.addConstrs( y1[t]<=c[t]-demand[t]+x*((-1)**t)+M*(1-z1[0,t]) for t in range(2))
    m.addConstrs( y1[t]<=M*(1-z2[0,t])  for t in range(2))
    m.addConstrs( z1[0,t]+z2[0,t]>=1 for t in range(2))
    
    m.addConstrs( y2[t]>=-c[t]+demand[t]-x*((-1)**t)  for t in range(2))
    m.addConstrs( y2[t]>=0 for t in range(2))
    m.addConstrs( y2[t]<=-c[t]+demand[t]-x*((-1)**t)+M*(1-z1[1,t]) for t in range(2))
    m.addConstrs( y2[t]<=M*(1-z2[1,t])  for t in range(2))
    m.addConstrs( z1[1,t]+z2[1,t]>=1 for t in range(2))


    
    #m.addConstr( x<=100000 )
    m.addConstr( x>=0 )
    m.addConstr( x<=max(demand[0]-c[0],0) )

    # Supressing the optimization output
    m.setParam( 'OutputFlag', False )

    # Solving the model
    m.optimize()
    
    return m,x

# %%
def flexibility_mode_actual(demand,c,cost_over,cost_under,x_predict):
    ######### Model Set-up ############
    m = Model()
    M=1e20

    #flexibility
    x = m.addVar(vtype=GRB.CONTINUOUS,name = "flexibility")#x
    y1= m.addVars(2,vtype=GRB.CONTINUOUS,name = "y1")
    y2= m.addVars(2,vtype=GRB.CONTINUOUS,name = "y2")
    z1 = m.addVars(2,2,vtype=GRB.BINARY,name='z1')
    z2 = m.addVars(2,2,vtype=GRB.BINARY,name='z2')

    # set objective
    m.setObjective( quicksum((cost_over[t]*y1[t]+cost_under[t]*y2[t]) for t in range(2)), GRB.MINIMIZE)#

    # add constraint
    
    m.addConstrs( y1[t]>=c[t]-demand[t]+x*((-1)**t)  for t in range(2))
    m.addConstrs( y1[t]>=0 for t in range(2))
    m.addConstrs( y1[t]<=c[t]-demand[t]+x*((-1)**t)+M*(1-z1[0,t]) for t in range(2))
    m.addConstrs( y1[t]<=M*(1-z2[0,t])  for t in range(2))
    m.addConstrs( z1[0,t]+z2[0,t]>=1 for t in range(2))
    
    m.addConstrs( y2[t]>=-c[t]+demand[t]-x*((-1)**t)  for t in range(2))
    m.addConstrs( y2[t]>=0 for t in range(2))
    m.addConstrs( y2[t]<=-c[t]+demand[t]-x*((-1)**t)+M*(1-z1[1,t]) for t in range(2))
    m.addConstrs( y2[t]<=M*(1-z2[1,t])  for t in range(2))
    m.addConstrs( z1[1,t]+z2[1,t]>=1 for t in range(2))

    
    #m.addConstr( x<=100000 )
    m.addConstr( x>=0 )
    m.addConstr( x<=max(demand[0]-c[0],0) )
    m.addConstr( x<=x_predict)

    # Supressing the optimization output
    m.setParam( 'OutputFlag', False )

    # Solving the model
    m.optimize()
    
    return m,x

# %%
def outcome_n(weekday,period,year):

    df1=data_select(weekday,period,year,'SZX','predict')
    df2=data_select(weekday,period,year,'HK','predict')


    c=[]
    demand1=np.array(df1['demand'])
    n1=len(demand1)
    weight1=np.array([1/n1]*n1)
    m1,c1=weighted_cluster_model(demand1,weight1,7.5,9)
    c.append(c1.x)
    
    demand2=np.array(df2['demand'])
    n2=len(demand2)
    weight2=np.array([1/n2]*n2)
    m2,c2=weighted_cluster_model(demand2,weight2,5.7,7.2)
    c.append(c2.x)
    
    df21=df1[['date','demand']]
    df21.rename(columns={'demand':'SZX_demand'},inplace=True)
    df22=df2[['date','demand']]
    df22.rename(columns={'demand':'HK_demand'},inplace=True)
    df_flex=pd.merge(df21,df22,how='outer',on='date')
    df_flex=df_flex.fillna(0)
    demand=np.array(df_flex[['SZX_demand','HK_demand']])
    
    cost_over=np.array([7.5,5.7])
    cost_under=np.array([9,7.2])
    
    for i in range(len(demand)):
        m,x=flexibility_model(demand[i],c,cost_over,cost_under)
        df_flex.loc[i,'x_predict']=x.x
        if df_flex.loc[i,'SZX_demand']==0:
            df_flex.loc[i,'pred_cost']=cost_over[1]*max(c[1]-df_flex.loc[i,'HK_demand'],0)+cost_under[1]*max(df_flex.loc[i,'HK_demand']-c[1],0)
        else:
            df_flex.loc[i,'pred_cost']=m.objVal
            
    df_flex['capacity_szx']=c1.x
    df_flex['capacity_hk']=c2.x
    
    # Actual flexibility
    d11=data_select(weekday,period,year,'SZX','real')
    d12=data_select(weekday,period,year,'HK','real')
    
    df_a=d11[['date','demand']]
    df_a.rename(columns={'demand':'SZX_demand_real'},inplace=True)
    df_b=d12[['date','demand']]
    df_b.rename(columns={'demand':'HK_demand_real'},inplace=True)
    df_flex=pd.merge(df_flex,df_a,how='outer',on='date')
    df_flex=pd.merge(df_flex,df_b,how='outer',on='date')
    df_flex=df_flex.fillna(0)
    
    for i in range(len(df_flex)):
        x_predict=df_flex.loc[i,'x_predict']
        demand1=df_flex.loc[i,'SZX_demand_real']
        demand2=df_flex.loc[i,'HK_demand_real']
        demand=[demand1,demand2]
        m,x=flexibility_mode_actual(demand,c,cost_over,cost_under,x_predict)
        df_flex.loc[i,'x_real']=x.x
        if df_flex.loc[i,'SZX_demand_real']==0:
            if df_flex.loc[i,'HK_demand_real']==0:
                df_flex.loc[i,'real_cost']=0
            else:
                df_flex.loc[i,'real_cost']=cost_over[1]*max(c[1]-df_flex.loc[i,'HK_demand_real'],0)+cost_under[1]*max(df_flex.loc[i,'HK_demand_real']-c[1],0)
        else :
            df_flex.loc[i,'real_cost']=m.objVal 
            
    obj_cost=df_flex['pred_cost'].sum()  
    print('predicted flexible obj cost:',obj_cost)
    print('='*50)
    
    real_cost=df_flex['real_cost'].sum()
    print('actual flexible obj cost:',real_cost)
    print('='*50)
    
    print(df_flex)

# %%
for y in (2019,2020):
    for j in (1,2,3):
        for i in (1,6):
            print('year',y,',period',j,',day',i)
            print(outcome_n(i,j,y))
            print("="*30,"*"*15,"="*30)
            print("   "*20)
            print("="*30,"*"*15,"="*30)
# Out:
# year 2019 ,period 1 ,day 1
# Using license file /Users/beijiale/gurobi.lic
# Academic license - for non-commercial use only
# predicted flexible obj cost: 14032843.200000001
# ==================================================
# actual flexible obj cost: 19956431.700000003
# ==================================================
#           date  SZX_demand  HK_demand  x_predict  pred_cost  capacity_szx  \
# 0   2019-01-07    335161.0   476872.0    73060.0    21211.2      262101.0
# 1   2019-01-14    344049.0   510309.0    81948.0   325951.2      262101.0
# 2   2019-01-21    350900.0   546986.0    88799.0   639352.8      262101.0
# 3   2019-01-28     10390.0   719708.0        0.0  3131430.9      262101.0
# 4   2019-02-04    145532.0   276723.0        0.0  2414766.6      262101.0
# 5   2019-02-18    190868.0   358772.0        0.0  1607067.3      262101.0
# 6   2019-02-25    235198.0   503676.0        0.0   448639.5      262101.0
# 7   2019-03-04    249073.0   598026.0        0.0   465198.0      262101.0
# 8   2019-03-11    262101.0   617137.0        0.0   505087.2      262101.0
# 9   2019-03-18    284475.0   640546.0    22374.0   834724.8      262101.0
# 10  2019-03-25    287863.0   638996.0    25762.0   847958.4      262101.0
# 11  2019-02-11         0.0    57257.0        0.0  2791455.3      262101.0
#
#     capacity_hk  SZX_demand_real  HK_demand_real   x_real  real_cost
# 0      546986.0         275263.0        455675.0  13162.0   445449.3
# 1      546986.0         285269.0        396620.0  23168.0   725028.6
# 2      546986.0         343699.0        542446.0  81598.0   554817.6
# 3      546986.0         458132.0        747576.0      0.0  3208527.0
# 4      546986.0          29327.0         93620.0      0.0  4329991.2
# 5      546986.0         130787.0        299528.0      0.0  2395365.6
# 6      546986.0         188140.0        369524.0      0.0  1566240.9
# 7      546986.0         250482.0        584591.0      0.0   357898.5
# 8      546986.0         269524.0        571383.0      0.0   242465.4
# 9      546986.0         325840.0        681930.0  22374.0  1504974.6
# 10     546986.0         300063.0        740421.0  25762.0  1688018.4
# 11     546986.0              0.0         31608.0      0.0  2937654.6
# None
# ============================== *************** ==============================
#
# ============================== *************** ==============================
# year 2019 ,period 1 ,day 6
# predicted flexible obj cost: 17180336.099999998
# ==================================================
# actual flexible obj cost: 27154451.999999996
# ==================================================
#           date  SZX_demand  HK_demand  x_predict  pred_cost  capacity_szx  \
# 0   2019-01-05    402192.0   570020.0        0.0   938760.3      412654.0
# 1   2019-01-12    603376.0   577927.0   190722.0   343440.0      412654.0
# 2   2019-01-19    608722.0   618413.0   196068.0   673430.4      412654.0
# 3   2019-01-26    620832.0   747363.0   208178.0  1689062.4      412654.0
# 4   2019-02-02    277017.0   385331.0        0.0  2930300.1      412654.0
# 5   2019-02-16    222956.0   381627.0        0.0  3356870.4      412654.0
# 6   2019-02-23    366439.0   497438.0        0.0  1620625.2      412654.0
# 7   2019-03-02    370296.0   727316.0        0.0   363527.4      412654.0
# 8   2019-03-09    392143.0   720949.0        0.0   153832.5      412654.0
# 9   2019-03-16    412654.0   743989.0        0.0   165888.0      412654.0
# 10  2019-03-23    447881.0   772209.0    35227.0   622706.4      412654.0
# 11  2019-03-30    453215.0   770341.0    40561.0   647661.6      412654.0
# 12  2019-02-09         0.0    76347.0        0.0  3674231.4      412654.0
#
#     capacity_hk  SZX_demand_real  HK_demand_real    x_real  real_cost
# 0      720949.0         616311.0        537985.0       0.0  2875807.8
# 1      720949.0         662716.0        587483.0  190722.0   946303.2
# 2      720949.0         625485.0        618846.0  196068.0   827415.0
# 3      720949.0         825152.0        764067.0  208178.0  3648211.2
# 4      720949.0         170158.0        274179.0       0.0  4365309.0
# 5      720949.0         332401.0        170867.0       0.0  3737364.9
# 6      720949.0         375251.0        383701.0       0.0  2202836.1
# 7      720949.0         414204.0        587629.0       0.0   773874.0
# 8      720949.0         464224.0        745155.0       0.0   638413.2
# 9      720949.0              0.0        812925.0       0.0   662227.2
# 10     720949.0         538807.0        772019.0   35227.0  1439672.4
# 11     720949.0         549157.0        636424.0   40561.0  1114072.8
# 12     720949.0              0.0         32713.0       0.0  3922945.2
# None
# ============================== *************** ==============================
#
# ============================== *************** ==============================
# year 2019 ,period 2 ,day 1
# predicted flexible obj cost: 26102541.3
# ==================================================
# actual flexible obj cost: 53435652.6
# ==================================================
#           date  SZX_demand  HK_demand  x_predict  pred_cost  capacity_szx  \
# 0   2019-04-01    239847.0   524552.0        0.0  1050855.0      379961.0
# 1   2019-04-08    153697.0   561968.0        0.0  1966375.2      379961.0
# 2   2019-04-15    305550.0   581410.0        0.0   967460.1      379961.0
# 3   2019-04-22    316132.0   508338.0        0.0   571137.3      379961.0
# 4   2019-04-29    304857.0   588748.0        0.0  1025491.2      379961.0
# 5   2019-05-06    344485.0   628954.0        0.0  1017764.4      379961.0
# 6   2019-05-13    306728.0   564285.0        0.0   835325.1      379961.0
# 7   2019-05-20    307515.0   636775.0        0.0  1351350.6      379961.0
# 8   2019-05-27    425055.0   622398.0    45094.0  1029168.0      379961.0
# 9   2019-06-03    389181.0   552363.0     9220.0   266623.2      379961.0
# 10  2019-06-10    196963.0   458961.0        0.0  1746353.7      379961.0
# 11  2019-06-17    412547.0   486301.0    32586.0    32290.5      379961.0
# 12  2019-06-24    382553.0   503455.0     2592.0   105478.5      379961.0
# 13  2019-07-01    371878.0   500059.0        0.0   200232.6      379961.0
# 14  2019-07-08    379961.0   499174.0        0.0   144654.6      379961.0
# 15  2019-07-15    385041.0   470301.0     5080.0   280274.7      379961.0
# 16  2019-07-22    376565.0   491316.0        0.0   214915.2      379961.0
# 17  2019-07-29    376552.0   493022.0        0.0   205288.5      379961.0
# 18  2019-08-05    384259.0   479043.0     4298.0   234902.7      379961.0
# 19  2019-08-12    412520.0   491802.0    32559.0     1088.7      379961.0
# 20  2019-08-19    411642.0   502210.0    31681.0    67240.8      379961.0
# 21  2019-08-26    431884.0   510320.0    51923.0   271375.2      379961.0
# 22  2019-09-02    439648.0   505852.0    59687.0   295106.4      379961.0
# 23  2019-09-09    485007.0   490187.0   105046.0   508903.2      379961.0
# 24  2019-09-16    220440.0   713614.0        0.0  2557653.9      379961.0
# 25  2019-09-23    371249.0   797131.0        0.0  2027908.8      379961.0
# 26  2019-09-30   1021363.0   873056.0   641402.0  7127323.2      379961.0
#
#     capacity_hk  SZX_demand_real  HK_demand_real    x_real  real_cost
# 0      524552.0         326277.0        699369.0       0.0  1661312.4
# 1      524552.0         153928.0        422544.0       0.0  2276693.1
# 2      524552.0         300763.0        710606.0       0.0  1933573.8
# 3      524552.0         307188.0        312949.0       0.0  1751934.6
# 4      524552.0         548204.0        757658.0       0.0  3192550.2
# 5      524552.0         424746.0        465160.0       0.0   741599.4
# 6      524552.0         285313.0        746188.0       0.0  2305639.2
# 7      524552.0         354856.0        787220.0       0.0  2079497.1
# 8      524552.0         285222.0        730854.0       0.0  2195916.9
# 9      524552.0         282344.0        762015.0       0.0  2441861.1
# 10     524552.0         200343.0        578371.0       0.0  1734631.8
# 11     524552.0         312284.0        845895.0       0.0  2821247.1
# 12     524552.0         295159.0        791373.0       0.0  2557126.2
# 13     524552.0         268795.0        701380.0       0.0  2106906.6
# 14     524552.0         262323.0        685879.0       0.0  2043839.4
# 15     524552.0         271657.0        631752.0       0.0  1584120.0
# 16     524552.0         273296.0        555267.0       0.0  1021135.5
# 17     524552.0         279599.0        687226.0       0.0  1923967.8
# 18     524552.0         313315.0        578081.0       0.0   885253.8
# 19     524552.0         325151.0        611687.0       0.0  1038447.0
# 20     524552.0         343571.0        637341.0       0.0  1085005.8
# 21     524552.0         409454.0        723474.0   29493.0  1644588.0
# 22     524552.0         289843.0        641589.0       0.0  1518551.4
# 23     524552.0         294726.0        642361.0       0.0  1487487.3
# 24     524552.0         188508.0        304791.0       0.0  2688535.2
# 25     524552.0         374820.0        758045.0       0.0  1719707.1
# 26     524552.0         861264.0        736933.0  481303.0  4994524.8
# None
# ============================== *************** ==============================
#
# ============================== *************** ==============================
# year 2019 ,period 2 ,day 6
# predicted flexible obj cost: 22070403.0
# ==================================================
# actual flexible obj cost: 30780583.799999997
# ==================================================
#           date  SZX_demand  HK_demand  x_predict  pred_cost  capacity_szx  \
# 0   2019-04-13    556095.0   702173.0        0.0   223986.3      569900.0
# 1   2019-04-20    616640.0   462400.0    46740.0  1004932.8      569900.0
# 2   2019-04-27    637997.0   800656.0    68097.0  1319824.8      569900.0
# 3   2019-05-04    615242.0   801116.0    45342.0  1159300.8      569900.0
# 4   2019-05-11    695217.0   776970.0   125317.0  1561269.6      569900.0
# 5   2019-05-18    619017.0   779216.0    49117.0  1028800.8      569900.0
# 6   2019-05-25    620607.0   786631.0    50707.0  1093636.8      569900.0
# 7   2019-06-01    560887.0   797529.0        0.0   874609.5      569900.0
# 8   2019-06-15    601803.0   648096.0    31903.0    31036.5      569900.0
# 9   2019-06-22    544384.0   686628.0        0.0   199894.8      569900.0
# 10  2019-06-29    504805.0   712134.0        0.0   680380.5      569900.0
# 11  2019-07-06    490717.0   646656.0        0.0   814964.1      569900.0
# 12  2019-07-13    501384.0   685444.0        0.0   513870.0      569900.0
# 13  2019-07-20    508086.0   645797.0        0.0   689592.9      569900.0
# 14  2019-07-27    496902.0   629250.0        0.0   867790.8      569900.0
# 15  2019-08-03    496885.0   631434.0        0.0   855469.5      569900.0
# 16  2019-08-10    507055.0   613531.0        0.0   881241.6      569900.0
# 17  2019-08-17    544348.0   629872.0        0.0   508400.4      569900.0
# 18  2019-08-24    543189.0   643202.0        0.0   441111.9      569900.0
# 19  2019-08-31    569900.0   653589.0        0.0   181573.5      569900.0
# 20  2019-09-07    580144.0   647866.0    10244.0   155803.8      569900.0
# 21  2019-09-21    618870.0   868426.0    48970.0  1670054.4      569900.0
# 22  2019-09-28    620117.0  1025955.0    50217.0  2813241.6      569900.0
# 23  2019-04-06         0.0   614322.0        0.0   405395.4      569900.0
# 24  2019-06-08         0.0   441218.0        0.0  1392088.2      569900.0
# 25  2019-09-14         0.0   562263.0        0.0   702131.7      569900.0
#
#     capacity_hk  SZX_demand_real  HK_demand_real   x_real  real_cost
# 0      685444.0         558729.0        710446.0      0.0   263796.9
# 1      685444.0         561078.0        629940.0      0.0   382537.8
# 2      685444.0         579661.0        712444.0   9761.0   264679.2
# 3      685444.0         221807.0        330436.0      0.0  4634243.1
# 4      685444.0         550379.0        741296.0      0.0   548541.9
# 5      685444.0         538091.0        756197.0      0.0   747989.1
# 6      685444.0         623377.0        727999.0  50707.0   696416.4
# 7      685444.0         495442.0        716971.0      0.0   785429.4
# 8      685444.0         523902.0        661610.0      0.0   480838.8
# 9      685444.0         547021.0        701118.0      0.0   284445.3
# 10     685444.0         551299.0        711215.0      0.0   325058.7
# 11     685444.0         530012.0        681854.0      0.0   319623.0
# 12     685444.0         512748.0        634030.0      0.0   721699.8
# 13     685444.0         575981.0        617109.0      0.0   444238.5
# 14     685444.0         567808.0        565044.0      0.0   701970.0
# 15     685444.0         484719.0        607650.0      0.0  1082283.3
# 16     685444.0         554213.0        617869.0      0.0   502830.0
# 17     685444.0         544708.0        573237.0      0.0   828519.9
# 18     685444.0         564858.0        541755.0      0.0   856842.3
# 19     685444.0         588754.0        637310.0      0.0   444049.8
# 20     685444.0         595018.0        595687.0  10244.0   587090.1
# 21     685444.0         727377.0        556791.0  48970.0  1430756.1
# 22     685444.0         791745.0        671113.0  50217.0  1803031.2
# 23     685444.0              0.0        273648.0      0.0  2347237.2
# 24     685444.0              0.0        228007.0      0.0  2607390.9
# 25     685444.0          43772.0        204201.0      0.0  6689045.1
# None
# ============================== *************** ==============================
#
# ============================== *************** ==============================
# year 2019 ,period 3 ,day 1
# predicted flexible obj cost: 16695303.000000002
# ==================================================
# actual flexible obj cost: 20592771.0
# ==================================================
#           date  SZX_demand  HK_demand  x_predict  pred_cost  capacity_szx  \
# 0   2019-10-14    374052.0   643353.0        0.0  2373822.0      531543.0
# 1   2019-10-21    382281.0   717718.0        0.0  1888224.0      531543.0
# 2   2019-10-28    378191.0   758882.0        0.0  1684264.2      531543.0
# 3   2019-11-04    377295.0   820709.0        0.0  1338570.3      531543.0
# 4   2019-11-11    554677.0   871050.0    23134.0   299491.2      531543.0
# 5   2019-11-18    531543.0   876667.0        0.0   173368.8      531543.0
# 6   2019-11-25    560232.0   886683.0    28689.0   452044.8      531543.0
# 7   2019-12-02    577296.0   938560.0    45753.0   948420.0      531543.0
# 8   2019-12-09    576920.0   913690.0    45377.0   766648.8      531543.0
# 9   2019-12-16    548680.0   852588.0    17137.0   123386.4      531543.0
# 10  2019-12-23    409006.0   763663.0        0.0  1425900.0      531543.0
# 11  2019-12-30    474814.0   507478.0        0.0  2392594.5      531543.0
# 12  2019-10-07         0.0   356348.0        0.0  2828568.0      531543.0
#
#     capacity_hk  SZX_demand_real  HK_demand_real  x_real  real_cost
# 0      852588.0         430584.0        848902.0     0.0   778202.7
# 1      852588.0         385407.0        837012.0     0.0  1184803.2
# 2      852588.0         471619.0        898395.0     0.0   779240.4
# 3      852588.0         448114.0        741752.0     0.0  1257482.7
# 4      852588.0         404537.0        907832.0     0.0  1350301.8
# 5      852588.0         514404.0       1006177.0     0.0  1234383.3
# 6      852588.0         437634.0        881977.0     0.0   915918.3
# 7      852588.0         503965.0        899935.0     0.0   547733.4
# 8      852588.0         425564.0        758267.0     0.0  1332472.2
# 9      852588.0         424756.0        877171.0     0.0   977900.1
# 10     852588.0         417898.0        786394.0     0.0  1229643.3
# 11     852588.0         292626.0        689805.0     0.0  2719740.6
# 12     852588.0          94408.0        325143.0     0.0  6284949.0
# None
# ============================== *************** ==============================
#
# ============================== *************** ==============================
# year 2019 ,period 3 ,day 6
# predicted flexible obj cost: 10979773.2
# ==================================================
# actual flexible obj cost: 26057418.6
# ==================================================
#           date  SZX_demand  HK_demand  x_predict  pred_cost  capacity_szx  \
# 0   2019-10-12    730326.0   809575.0     6316.0   442439.7      724010.0
# 1   2019-10-19    638506.0   873901.0        0.0   753062.7      724010.0
# 2   2019-10-26    627978.0   899729.0        0.0   765002.4      724010.0
# 3   2019-11-02    633854.0   906713.0        0.0   771217.2      724010.0
# 4   2019-11-09    651184.0   916192.0        0.0   709491.0      724010.0
# 5   2019-11-16    731923.0   877758.0     7913.0    44693.7      724010.0
# 6   2019-11-23    701399.0   883417.0        0.0   227124.0      724010.0
# 7   2019-11-30    739263.0   893512.0    15253.0   109821.6      724010.0
# 8   2019-12-07    761780.0   945945.0    37770.0   649461.6      724010.0
# 9   2019-12-14    761275.0   920881.0    37265.0   465364.8      724010.0
# 10  2019-12-21    724010.0   859279.0        0.0   195128.1      724010.0
# 11  2019-12-28    539705.0   586274.0        0.0  3133544.1      724010.0
# 12  2019-10-05         0.0   417473.0        0.0  2713422.3      724010.0
#
#     capacity_hk  SZX_demand_real  HK_demand_real   x_real  real_cost
# 0      893512.0         744959.0        702378.0   6316.0  1185159.6
# 1      893512.0         706073.0        700736.0      0.0  1233350.7
# 2      893512.0         753441.0        705585.0      0.0  1336062.9
# 3      893512.0         765638.0        673714.0      0.0  1627500.6
# 4      893512.0         843779.0        771264.0      0.0  1774734.6
# 5      893512.0         870406.0        848760.0   7913.0  1456329.3
# 6      893512.0         828780.0        703572.0      0.0  2025588.0
# 7      893512.0         717854.0        807065.0      0.0   538917.9
# 8      893512.0         740002.0        815523.0  15992.0   353382.9
# 9      893512.0         900516.0        879844.0  37265.0  1423067.4
# 10     893512.0         896623.0        767300.0      0.0  2272925.4
# 11     893512.0         612062.0        676420.0      0.0  2077034.4
# 12     893512.0          61616.0        229405.0      0.0  8753364.9
# None
# ============================== *************** ==============================
#
# ============================== *************** ==============================
# year 2020 ,period 1 ,day 1
# predicted flexible obj cost: 23390063.7
# ==================================================
# actual flexible obj cost: 35820397.8
# ==================================================
#           date  SZX_demand  HK_demand  x_predict  pred_cost  capacity_szx  \
# 0   2020-01-06    470294.0   586956.0   113323.0   161928.0      356971.0
# 1   2020-01-13    510656.0   759154.0   153685.0  1692360.0      356971.0
# 2   2020-01-20    535898.0   932817.0   178927.0  3124476.0      356971.0
# 3   2020-02-03    128440.0    50159.0        0.0  5291473.5      356971.0
# 4   2020-02-10    227839.0   231256.0        0.0  3513728.1      356971.0
# 5   2020-02-17    288731.0   389330.0        0.0  2156016.3      356971.0
# 6   2020-02-24    333609.0   545983.0        0.0   926509.2      356971.0
# 7   2020-03-02    340047.0   677789.0        0.0   126930.0      356971.0
# 8   2020-03-09    356971.0   752716.0        0.0   539474.4      356971.0
# 9   2020-03-16    372840.0   778031.0    15869.0   835999.2      356971.0
# 10  2020-03-23    387100.0   760449.0    30129.0   812080.8      356971.0
# 11  2020-03-30    320996.0   629320.0        0.0   546085.8      356971.0
# 12  2020-01-27         0.0    35157.0        0.0  3663002.4      356971.0
#
#     capacity_hk  SZX_demand_real  HK_demand_real    x_real  real_cost
# 0      677789.0         334737.0        563228.0       0.0   819752.7
# 1      677789.0         306893.0        642239.0       0.0   578220.0
# 2      677789.0         619007.0       1000038.0  178927.0  4356448.2
# 3      677789.0           5108.0         44007.0       0.0  6251529.9
# 4      677789.0              0.0         43878.0       0.0  3613292.7
# 5      677789.0         118997.0        210763.0       0.0  4446853.2
# 6      677789.0         208147.0        312583.0       0.0  3197854.2
# 7      677789.0         255694.0        445441.0       0.0  2083961.1
# 8      677789.0         310647.0        760916.0       0.0   945944.4
# 9      677789.0         507063.0        781653.0   15869.0  2070084.6
# 10     677789.0         466407.0        796705.0   30129.0  1786887.0
# 11     677789.0         613656.0       1144373.0       0.0  5669569.8
# 12     677789.0              0.0             0.0       0.0        0.0
# None
# ============================== *************** ==============================
#
# ============================== *************** ==============================
# year 2020 ,period 1 ,day 6
# predicted flexible obj cost: 29678986.5
# ==================================================
# actual flexible obj cost: 36272280.6
# ==================================================
#           date  SZX_demand  HK_demand  x_predict  pred_cost  capacity_szx  \
# 0   2020-01-04    582898.0   763910.0   111858.0  1301580.0      471040.0
# 1   2020-01-11    620577.0   775168.0   149537.0  1653926.4      471040.0
# 2   2020-01-18    673837.0   945299.0   202797.0  3262341.6      471040.0
# 3   2020-02-01     58120.0   130935.0        0.0  6312030.6      471040.0
# 4   2020-02-08    169479.0   157414.0        0.0  5325907.8      471040.0
# 5   2020-02-15    300643.0   325423.0        0.0  3384526.5      471040.0
# 6   2020-02-22    380993.0   409434.0        0.0  2303038.8      471040.0
# 7   2020-02-29    440212.0   504204.0        0.0  1318707.3      471040.0
# 8   2020-03-07    448708.0   625844.0        0.0   561639.3      471040.0
# 9   2020-03-14    471040.0   694993.0        0.0        0.0      471040.0
# 10  2020-03-21    491980.0   718355.0    20940.0   318974.4      471040.0
# 11  2020-03-28    510797.0   787732.0    39757.0   953971.2      471040.0
# 12  2020-01-25         0.0   171775.0        0.0  2982342.6      471040.0
#
#     capacity_hk  SZX_demand_real  HK_demand_real    x_real  real_cost
# 0      694993.0         666262.0        581541.0  111858.0   759361.8
# 1      694993.0         636540.0        580701.0  149537.0   397431.0
# 2      694993.0         761227.0        852348.0  202797.0  3379604.4
# 3      694993.0              0.0         25990.0       0.0  3813317.1
# 4      694993.0              0.0        122566.0       0.0  3262833.9
# 5      694993.0         142999.0        285535.0       0.0  4794218.1
# 6      694993.0         284773.0        265936.0       0.0  3842627.4
# 7      694993.0         594572.0        633596.0       0.0  1461750.9
# 8      694993.0         640618.0        634969.0       0.0  1868338.8
# 9      694993.0         641633.0        769470.0       0.0  2071571.4
# 10     694993.0         660714.0        666590.0   20940.0  1561145.1
# 11     694993.0         902930.0        874114.0   39757.0  5105118.6
# 12     694993.0              0.0          1140.0       0.0  3954962.1
# None
# ============================== *************** ==============================
#
# ============================== *************** ==============================
# year 2020 ,period 2 ,day 1
# predicted flexible obj cost: 22209048.000000004
# ==================================================
# actual flexible obj cost: 60087359.699999996
# ==================================================
#           date  SZX_demand  HK_demand  x_predict  pred_cost  capacity_szx  \
# 0   2020-04-13    302610.0   338160.0        0.0  2150087.7      387994.0
# 1   2020-04-20    313796.0   569416.0        0.0   748033.5      387994.0
# 2   2020-04-27    362955.0   700870.0        0.0   892305.3      387994.0
# 3   2020-05-11    342086.0   727397.0        0.0  1239817.2      387994.0
# 4   2020-05-18    326040.0   735294.0        0.0  1417020.6      387994.0
# 5   2020-05-25    365263.0   751277.0        0.0  1237925.7      387994.0
# 6   2020-06-01    388952.0   707401.0      958.0   758433.6      387994.0
# 7   2020-06-08    389974.0   688898.0     1980.0   632570.4      387994.0
# 8   2020-06-15    406096.0   690313.0    18102.0   758836.8      387994.0
# 9   2020-06-22    425383.0   753933.0    37389.0  1355767.2      387994.0
# 10  2020-06-29    429806.0   656876.0    41812.0   688802.4      387994.0
# 11  2020-07-06    322114.0   614735.0        0.0   578440.8      387994.0
# 12  2020-07-13    311471.0   578150.0        0.0   715687.2      387994.0
# 13  2020-07-20    370718.0   594974.0        0.0   175437.9      387994.0
# 14  2020-07-27    366883.0   603021.0        0.0   158332.5      387994.0
# 15  2020-08-03    366694.0   555036.0        0.0   433264.5      387994.0
# 16  2020-08-10    387994.0   571694.0        0.0   178563.9      387994.0
# 17  2020-08-17    396957.0   593699.0     8963.0     2046.3      387994.0
# 18  2020-08-24    413033.0   638487.0    25039.0   435636.0      387994.0
# 19  2020-08-31    439171.0   600849.0    51177.0   352836.0      387994.0
# 20  2020-09-07    459578.0   597270.0    71584.0   473997.6      387994.0
# 21  2020-09-14    313490.0   524539.0        0.0  1006127.4      387994.0
# 22  2020-09-21    338749.0   526247.0        0.0   806949.3      387994.0
# 23  2020-09-28    564545.0   591294.0   176551.0  1186732.8      387994.0
# 24  2020-04-06         0.0   296678.0        0.0  1746155.1      387994.0
# 25  2020-05-04         0.0   238242.0        0.0  2079240.3      387994.0
#
#     capacity_hk  SZX_demand_real  HK_demand_real    x_real  real_cost
# 0      603021.0         230656.0        815230.0       0.0  2707939.8
# 1      603021.0         438073.0        713930.0       0.0  1249255.8
# 2      603021.0         541591.0        839072.0       0.0  3081940.2
# 3      603021.0         666338.0        953152.0       0.0  5026039.2
# 4      603021.0         391028.0        599759.0       0.0    45899.4
# 5      603021.0         344030.0        807136.0       0.0  1799358.0
# 6      603021.0         426502.0        767139.0     958.0  1526497.2
# 7      603021.0         449853.0       1075785.0    1980.0  3957067.8
# 8      603021.0         468016.0        844043.0   18102.0  2422972.8
# 9      603021.0         465276.0       1341161.0   37389.0  5942845.8
# 10     603021.0         706157.0        896730.0   41812.0  4902910.2
# 11     603021.0         490906.0        901059.0       0.0  3072081.6
# 12     603021.0         443966.0        931482.0       0.0  2868667.2
# 13     603021.0         350965.0        914628.0       0.0  2521287.9
# 14     603021.0         422188.0        799563.0       0.0  1722848.4
# 15     603021.0         235553.0        544724.0       0.0  1475600.4
# 16     603021.0         265336.0        759794.0       0.0  2048700.6
# 17     603021.0         361795.0        860483.0       0.0  2050218.9
# 18     603021.0         429792.0        861356.0   25039.0  2191123.8
# 19     603021.0         365572.0        647033.0       0.0   485051.4
# 20     603021.0         400622.0        596476.0   12628.0    43797.6
# 21     603021.0         379705.0        742600.0       0.0  1067136.3
# 22     603021.0         421416.0        811093.0       0.0  1798916.4
# 23     603021.0         756637.0        776900.0  176551.0  4251924.0
# 24     603021.0              0.0        381663.0       0.0  1261740.6
# 25     603021.0              0.0        681568.0       0.0   565538.4
# None
# ============================== *************** ==============================
#
# ============================== *************** ==============================
# year 2020 ,period 2 ,day 6
# predicted flexible obj cost: 25279349.7
# ==================================================
# actual flexible obj cost: 104659605.6
# ==================================================
#           date  SZX_demand  HK_demand  x_predict  pred_cost  capacity_szx  \
# 0   2020-04-04    406229.0   619535.0        0.0  1318755.9      567158.0
# 1   2020-04-11    639951.0   546160.0    72793.0   115105.8      567158.0
# 2   2020-04-18    615337.0   615936.0    48179.0   179769.6      567158.0
# 3   2020-04-25    636858.0   684705.0    69700.0   829857.6      567158.0
# 4   2020-05-09    696275.0   691893.0   129117.0  1309413.6      567158.0
# 5   2020-05-16    683771.0   712350.0   116613.0  1366675.2      567158.0
# 6   2020-05-23    602035.0   720335.0    34877.0   835668.0      567158.0
# 7   2020-05-30    481989.0   735866.0        0.0  1335144.3      567158.0
# 8   2020-06-06    513249.0   720627.0        0.0   990973.5      567158.0
# 9   2020-06-13    514598.0   701778.0        0.0   845143.2      567158.0
# 10  2020-06-20    535872.0   749437.0        0.0  1028733.0      567158.0
# 11  2020-07-04    567158.0   725280.0        0.0   620157.6      567158.0
# 12  2020-07-11    425050.0   626229.0        0.0  1139442.6      567158.0
# 13  2020-07-18    411007.0   588960.0        0.0  1457198.4      567158.0
# 14  2020-07-25    489187.0   606099.0        0.0   773156.1      567158.0
# 15  2020-08-01    484127.0   595607.0        0.0   870910.5      567158.0
# 16  2020-08-08    483877.0   593952.0        0.0   882219.0      567158.0
# 17  2020-08-15    511985.0   611777.0        0.0   569806.5      567158.0
# 18  2020-08-22    523810.0   635324.0        0.0   346901.1      567158.0
# 19  2020-08-29    545025.0   683252.0        0.0   483553.5      567158.0
# 20  2020-09-05    579515.0   684294.0    12357.0   414028.8      567158.0
# 21  2020-09-12    606444.0   639147.0    39286.0   282859.2      567158.0
# 22  2020-09-19    773874.0   631051.0   206716.0  1430064.0      567158.0
# 23  2020-09-26    836230.0   633106.0   269072.0  1893823.2      567158.0
# 24  2020-05-02         0.0   298685.0        0.0  1940633.4      567158.0
# 25  2020-06-27         0.0   284874.0        0.0  2019356.1      567158.0
#
#     capacity_hk  SZX_demand_real  HK_demand_real    x_real  real_cost
# 0      639147.0         625852.0        946804.0       0.0  2743376.4
# 1      639147.0         584559.0        610375.0   17401.0    64814.7
# 2      639147.0         601927.0        875154.0   34769.0  1949587.2
# 3      639147.0         489746.0        773092.0       0.0  1544994.0
# 4      639147.0        1100060.0       1046288.0  129117.0  7495122.6
# 5      639147.0         690400.0        652345.0  116613.0   994300.2
# 6      639147.0         815878.0        919214.0   34877.0  4192183.8
# 7      639147.0         961702.0        896014.0       0.0  5400338.4
# 8      639147.0        1089825.0       1054457.0       0.0  7694235.0
# 9      639147.0        1246490.0        563774.0       0.0  6543614.1
# 10     639147.0        1296677.0        593120.0       0.0  6828024.9
# 11     639147.0         987239.0       1073221.0       0.0  6906061.8
# 12     639147.0         967378.0        869960.0       0.0  5263833.6
# 13     639147.0         770997.0        742654.0       0.0  2579801.4
# 14     639147.0         874240.0        951608.0       0.0  5013457.2
# 15     639147.0         638124.0        574305.0       0.0  1008293.4
# 16     639147.0         534976.0        567104.0       0.0   652010.1
# 17     639147.0         787698.0        730484.0       0.0  2642486.4
# 18     639147.0         925679.0        880344.0       0.0  4963307.4
# 19     639147.0        1015008.0        762713.0       0.0  4920325.2
# 20     639147.0        1092178.0        744039.0   12357.0  5458159.8
# 21     639147.0        1044391.0        779463.0   39286.0  5234657.4
# 22     639147.0        1106808.0        877993.0  206716.0  6204452.4
# 23     639147.0        1181990.0        888181.0  269072.0  6842203.2
# 24     639147.0              0.0        544689.0       0.0   538410.6
# 25     639147.0              0.0        775474.0       0.0   981554.4
# None
# ============================== *************** ==============================
#
# ============================== *************** ==============================
# year 2020 ,period 3 ,day 1
# predicted flexible obj cost: 3126355.1999999997
# ==================================================
# actual flexible obj cost: 9166109.4
# ==================================================
#          date  SZX_demand  HK_demand  x_predict  pred_cost  capacity_szx  \
# 0  2020-10-12    645493.0   576727.0   302265.0  2176308.0      343228.0
# 1  2020-10-19    343228.0   619699.0        0.0   309398.4      343228.0
# 2  2020-10-26    327317.0   543535.0        0.0   308526.9      343228.0
# 3  2020-10-05         0.0   518460.0        0.0   332121.9      343228.0
#
#    capacity_hk  SZX_demand_real  HK_demand_real   x_real  real_cost
# 0     576727.0         363652.0        730763.0  20424.0  1256112.0
# 1     576727.0         415290.0       1074011.0      0.0  4229002.8
# 2     576727.0         443240.0        680569.0      0.0  1647770.4
# 3     576727.0              0.0        220021.0      0.0  2033224.2
# None
# ============================== *************** ==============================
#
# ============================== *************** ==============================
# year 2020 ,period 3 ,day 6
# predicted flexible obj cost: 6667851.0
# ==================================================
# actual flexible obj cost: 10345113.0
# ==================================================
#          date  SZX_demand  HK_demand  x_predict  pred_cost  capacity_szx  \
# 0  2020-10-10    410450.0   623739.0        0.0  3455570.1      817922.0
# 1  2020-10-17    817922.0   693832.0        0.0        0.0      817922.0
# 2  2020-10-24    847286.0   745526.0    29364.0   583617.6      817922.0
# 3  2020-10-03         0.0   232663.0        0.0  2628663.3      817922.0
#
#    capacity_hk  SZX_demand_real  HK_demand_real  x_real  real_cost
# 0     693832.0         590654.0        806541.0     0.0  2516014.8
# 1     693832.0        1069658.0        890776.0     0.0  3683620.8
# 2     693832.0         658848.0        770029.0     0.0  1741673.4
# 3     693832.0              0.0        272112.0     0.0  2403804.0
# None
# ============================== *************** ==============================
#
# ============================== *************** ==============================
